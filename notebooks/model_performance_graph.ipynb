# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('ggplot')

# %%
data = pd.read_csv('../models/model_history/CNN_E2_Batch32_Filters32_Neurons32_Actrelu.csv')

# %%
# data1 = pd.read_csv('../models/model_history/First.txt', sep=",", header=None)

# %%
data
# Out:
#    accuracy  precision_2  val_loss  val_accuracy      loss  val_precision_2  \
# 0  0.838238     0.866463  0.253217      0.901130  0.387203         0.958065
# 1  0.911013     0.924982  0.189459      0.922316  0.221571         0.951662
#
#    val_recall_2  recall_2
# 0      0.838983  0.799930
# 1      0.889831  0.894681

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_loss'], label = 'Test Loss')
ax.plot(data['loss'], label = 'Training Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Model Loss')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_accuracy'], label = 'Test Accuracy')
ax.plot(data['accuracy'], label = 'Training Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_precision'], label = 'Test Precision')
ax.plot(data['precision'], label = 'Training Precision')
ax.plot(data['val_recall'], label = 'Test Recall')
ax.plot(data['recall'], label = 'Training Recall')
ax.set_xlabel('Epoch')
ax.set_ylabel('Rate')
ax.set_title('Model Precision & Recall')
ax.legend()
