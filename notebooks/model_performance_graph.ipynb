# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('ggplot')

# %%
data = pd.read_csv('../models/model_history/CNN_E100_Batch10_Filters64_Neurons64_Actrelu_Layers_3.csv')

# %%
# data1 = pd.read_csv('../models/model_history/First.txt', sep=",", header=None)

# %%
name = '{} Epochs, {} Batch Size, {} Filters, {} Neurons, {} Activation'.format(25, 32, 64, 64, 'Relu')

# %%
data
# Out:
#     recall_2  accuracy  val_precision_2  precision_2      loss  val_accuracy  \
# 0   0.839028  0.845991         0.975535     0.851018  0.351726      0.939266
# 1   0.911236  0.933040         0.990385     0.952855  0.193372      0.932203
# 2   0.938711  0.956123         0.993730     0.972628  0.125479      0.944915
# 3   0.947165  0.959295         0.971671     0.970758  0.106438      0.970339
# 4   0.960902  0.967753         0.961003     0.974286  0.090285      0.967514
# ..       ...       ...              ...          ...       ...           ...
# 95  0.999296  0.999119         0.985673     0.998944  0.002030      0.978814
# 96  0.998591  0.998414         0.980000     0.998239  0.005468      0.974576
# 97  0.997182  0.997004         0.982955     0.996831  0.007338      0.980226
# 98  0.991899  0.993304         0.994169     0.994701  0.025656      0.978814
# 99  0.999296  0.999295         1.000000     0.999296  0.001813      0.983051
#
#     val_recall_2  val_loss
# ...

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_loss'], label = 'Test Loss')
ax.plot(data['loss'], label = 'Training Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Model Loss')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_accuracy'], label = 'Test Accuracy')
ax.plot(data['accuracy'], label = 'Training Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_precision_2'], label = 'Test Precision')
ax.plot(data['precision_2'], label = 'Training Precision')
ax.plot(data['val_recall_2'], label = 'Test Recall')
ax.plot(data['recall_2'], label = 'Training Recall')
ax.set_xlabel('Epoch')
ax.set_ylabel('Rate')
ax.set_title('Model Precision & Recall')
ax.legend()
