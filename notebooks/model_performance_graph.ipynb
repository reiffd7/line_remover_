# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('ggplot')

# %%
data = pd.read_csv('../models/model_history/moredata_CNN_E100_Batch10_Filters64_Neurons64_Actrelu_Layers_3.csv')

# %%
# data1 = pd.read_csv('../models/model_history/First.txt', sep=",", header=None)

# %%
name = '{} Epochs, {} Batch Size, {} Filters, {} Neurons, {} Activation'.format(100, 10, 64, 64, 'Relu')

# %%
data
# Out:
#     val_recall      loss  val_loss  val_accuracy    recall  accuracy  \
# 0     0.924429  0.280433  0.145263      0.949868  0.884666  0.885127
# 1     0.961336  0.160607  0.093171      0.963940  0.931898  0.942508
# 2     0.978910  0.106135  0.061623      0.978892  0.955624  0.961416
# 3     0.964851  0.087308  0.059975      0.977133  0.963533  0.965703
# 4     0.975395  0.080179  0.066199      0.978012  0.969903  0.970650
# ..         ...       ...       ...           ...       ...       ...
# 95    0.980668  0.020578  0.046260      0.985928  0.995826  0.996263
# 96    0.984183  0.011027  0.119996      0.984169  0.997144  0.996922
# 97    0.989455  0.014539  0.149189      0.989446  0.996485  0.997032
# 98    0.982425  0.012898  0.089902      0.984169  0.997803  0.997582
# 99    0.980668  0.003008  0.178776      0.984169  0.999121  0.999231
#
#     val_precision  precision
# 0        0.974074   0.885639
# 1        0.966431   0.952189
# 2        0.978910   0.966882
# ...

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_loss'], label = 'Test Loss')
ax.plot(data['loss'], label = 'Training Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Model Loss')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_accuracy'], label = 'Test Accuracy')
ax.plot(data['accuracy'], label = 'Training Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_precision'], label = 'Test Precision')
ax.plot(data['precision'], label = 'Training Precision')
ax.plot(data['val_recall'], label = 'Test Recall')
ax.plot(data['recall'], label = 'Training Recall')
ax.set_xlabel('Epoch')
ax.set_ylabel('Rate')
ax.set_title('Model Precision & Recall')
ax.legend()
