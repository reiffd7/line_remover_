# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('ggplot')

# %%
data = pd.read_csv('../models/model_history/CNN_E25_Batch32_Filters64_Neurons64_Actrelu.csv')

# %%
# data1 = pd.read_csv('../models/model_history/First.txt', sep=",", header=None)

# %%
name = '{} Epochs, {} Batch Size, {} Filters, {} Neurons, {} Activation'.format(25, 32, 64, 64, 'Relu')

# %%
data
# Out:
#         loss  accuracy  val_recall_1  val_precision_1  val_accuracy  \
# 0   0.330249  0.856740      0.909605         0.938776      0.925141
# 1   0.175711  0.932687      0.901130         0.987616      0.944915
# 2   0.128433  0.952423      0.963277         0.947222      0.954802
# 3   0.097952  0.962291      0.980226         0.915567      0.944915
# 4   0.078141  0.972159      0.968927         0.977208      0.973164
# 5   0.061501  0.977621      0.963277         0.966006      0.964689
# 6   0.056306  0.976916      0.974576         0.966387      0.970339
# 7   0.051900  0.981145      0.980226         0.961219      0.970339
# 8   0.041208  0.985374      0.980226         0.948087      0.963277
# 9   0.034961  0.988018      0.966102         0.974359      0.970339
# 10  0.029262  0.988546      0.974576         0.963687      0.968927
# 11  0.028206  0.988722      0.963277         0.979885      0.971751
# 12  0.035440  0.986960      0.988701         0.958904      0.973164
# 13  0.021850  0.991718      0.985876         0.974860      0.980226
# 14  0.019812  0.993833      0.963277         0.971510      0.967514
# 15  0.027907  0.989603      0.957627         0.988338      0.973164
# 16  0.025949  0.990485      0.935028         0.996988      0.966102
# 17  0.013877  0.995418      0.991525         0.953804      0.971751
# 18  0.020323  0.992423      0.968927         0.971671      0.970339
# 19  0.014051  0.995595      0.957627         0.991228      0.974576
# 20  0.018174  0.992951      0.983051         0.969359      0.975989
# 21  0.013218  0.995066      0.991525         0.948649      0.968927
# 22  0.013602  0.995242      0.991525         0.956403      0.973164
# 23  0.018430  0.994185      0.949152         0.988235      0.968927
# 24  0.018690  0.995242      0.985876         0.969444      0.977401
#
#     precision_1  val_loss  recall_1
# 0      0.895703  0.187981  0.807679
# 1      0.947215  0.151178  0.916520
# 2      0.962217  0.111923  0.941881
# 3      0.965591  0.125124  0.958788
# 4      0.974178  0.071070  0.970060
# 5      0.978476  0.073304  0.976752
# 6      0.978445  0.070813  0.975343
# 7      0.980647  0.065614  0.981684
# 8      0.986239  0.089206  0.984502
# 9      0.986995  0.065791  0.989081
# 10     0.989414  0.064816  0.987672
# 11     0.987355  0.078991  0.990137
# 12     0.986624  0.072499  0.987319
# 13     0.992243  0.053623  0.991194
# 14     0.994010  0.142523  0.993660
# 15     0.989437  0.067074  0.989785
# 16     0.990490  0.102669  0.990490
# 17     0.995072  0.093303  0.995773
# 18     0.992948  0.091777  0.991899
# 19     0.995074  0.081868  0.996125
# 20     0.993651  0.059097  0.992251
# 21     0.994372  0.080195  0.995773
# 22     0.995419  0.095629  0.995069
# 23     0.994014  0.111670  0.994364
# 24     0.994374  0.074353  0.996125

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_loss'], label = 'Test Loss')
ax.plot(data['loss'], label = 'Training Loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Model Loss')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_accuracy'], label = 'Test Accuracy')
ax.plot(data['accuracy'], label = 'Training Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(data['val_precision_1'], label = 'Test Precision')
ax.plot(data['precision_1'], label = 'Training Precision')
ax.plot(data['val_recall_1'], label = 'Test Recall')
ax.plot(data['recall_1'], label = 'Training Recall')
ax.set_xlabel('Epoch')
ax.set_ylabel('Rate')
ax.set_title('Model Precision & Recall')
ax.legend()
